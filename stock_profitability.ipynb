# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
d = {'stockA': [25,-10,10,5,35,13], 'stockB': [0,15,-5,5,20,25],'stockC': [10,25,-15,-5,-5,15]}
df = pd.DataFrame(data=d, dtype=np.int8)
df
# Out:
#    stockA  stockB  stockC
# 0      25       0      10
# 1     -10      15      25
# 2      10      -5     -15
# 3       5       5      -5
# 4      35      20      -5
# 5      13      25      15

# %%
sns.regplot(x=df.stockA, y=df.stockB, ci=None)
# Out:
# <AxesSubplot:xlabel='stockA', ylabel='stockB'>

# %%
sns.regplot(x=df.stockB, y=df.stockC)
# Out:
# <AxesSubplot:xlabel='stockB', ylabel='stockC'>

# %%
sns.regplot(x=df.stockA, y=df.stockC)
# Out:
# <AxesSubplot:xlabel='stockA', ylabel='stockC'>
